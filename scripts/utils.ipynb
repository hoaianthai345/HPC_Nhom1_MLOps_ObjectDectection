# %% [markdown]
# ## Remove bucket

# %%
import boto3

s3 = boto3.client(
    "s3",
    endpoint_url="http://localhost:9000",
    aws_access_key_id="minio_admin",
    aws_secret_access_key="minio_password123",
)

s3.delete_bucket(Bucket="production-predictions")

print("Bucket deleted.")
